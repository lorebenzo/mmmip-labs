# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.signal import convolve
import lib

# %%
np.random.seed(12345)

# %% [markdown]
# Local Polynomial Approximation
# -------------------------------
# Set the parameters

# %%
# # maximum degree of polynomial used for fitting
# N = 2

# # filter size
# M = 51

# large M, small N -> a lot of bias when frequency increases
# N = 2
# M = 51

# large M, large N -> smaller bias than before, but a lot of variance in smooth regions
N = 7
M = 51

# small M, small N -> smaller bias everywhere, higher variance
# N = 2
# M = 5

# M small, M = N,  -> smaller bias than before, higher variance than before
# N = 5
# N = M

# %% [markdown]
# Generate synthetic signal signal

# %%
LENGHT = 1000

ty = np.linspace(0, 1, LENGHT)
y = np.sin(2 / (ty + 0.05))

# noise standard deviation
sigma = 0.1

# noisy signal
s = y + sigma * np.random.normal(size=LENGHT)

# %%
plt.figure(figsize=(10, 5))
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=2)
plt.grid()
plt.legend(['noisy', 'original'])
plt.title('Input Signal')
# Out:
# Text(0.5, 1.0, 'Input Signal')

# %% [markdown]
# Define the matrix T containing the polynomials sampled over the window

# %%
t = np.linspace(-1, 1, M)
T = np.column_stack([t**i for i in range(N+1)])

# %% [markdown]
# Look at the matrix T, the columns correspond to polynomials sampled over the interval [0,1]

# %%
plt.figure()
leg = []
for l in range(N+1):
    plt.plot(t, T[:, l])
    leg.append(f't^{l:d}')
plt.legend(leg)

# %% [markdown]
# Construct the LPA kernel

# %%
# comput the qr decomposition of WT
# since T has more rows than columns, then qr computes only the first N + 1 columns of Q and the first N + 1 rows of R.
Q, R = np.linalg.qr(T)

# select the central row of W2Qtilde
row = M // 2

# compute the kernel
g = np.sum(Q[row, l] * Q[:, l] for l in range(N+1))

# flipping, since it is used in convolution
g = g[::-1]
# Out:
# /var/folders/w2/bgswx5pn3hjb55_vz5h2hw4m0000gn/T/ipykernel_65061/1407702183.py:9: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   g = np.sum(Q[row, l] * Q[:, l] for l in range(N+1))

# %%
plt.figure()
plt.plot(g, 'rs', linewidth=3)
plt.title(f'M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'M = 51, N = 7')

# %% [markdown]
# Filtering

# %%
# convolution
shat = convolve(s, g, 'same')

# %%
plt.figure(figsize=(10,10))
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=3)
plt.plot(ty, shat, 'm-', linewidth=3)
plt.grid()
plt.legend(['noisy', 'original', 'LPA estimate'])
plt.title(f'M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'M = 51, N = 7')

# %% [markdown]
# Weighted LPA
# --------------
# Set the parameters

# %%
# maximum degree of polynomial used for fitting
N = 2

# filter size
M = 53

# half filter size
HFS = int((M -1 ) / 2)

# set the weights. Here weights simply define the window size
w = np.zeros(M)

# centered kernel
wc = w.copy()
wc[int(HFS / 2):-int(HFS / 2)] = 1

# left kernel
wl = w.copy()
wl[:HFS+1] = 1

# right kernel
wr = w.copy()
wr[-HFS-1:] = 1

# %%
fig, ax = plt.subplots(3, 1, figsize=(10,10))
ax[0].plot(wc, 'rs', linewidth=3)
ax[0].set_title('centered weights')
ax[0].grid()
ax[1].plot(wl, 'bs', linewidth=3)
ax[1].set_title('left weights')
ax[1].grid()
ax[2].plot(wr, 'ms', linewidth=3)
ax[2].set_title('right weights')
ax[2].grid()

# %% [markdown]
# Build the weight matrix

# %%
# select a single weight to be used in what follows
w = wc

# generate the inverse of weights
winv = 1 / w


# set to zero weights that are inf
winv = np.where(winv == np.inf, 0, winv)
# define the weight matrix
W = np.diag(w)
Winv = np.diag(winv)
# Out:
# /var/folders/w2/bgswx5pn3hjb55_vz5h2hw4m0000gn/T/ipykernel_65061/3844980146.py:5: RuntimeWarning: divide by zero encountered in divide
#   winv = 1 / w

# %% [markdown]
# Generate synthetic signal signal

# %%
LENGHT = 1000

# clean signal
ty = np.linspace(0, 1, LENGHT)
y =  8*ty**2 - 2*ty + 2
y[LENGHT//2 : LENGHT] = y[LENGHT//2 : LENGHT] + 7

#  noise standard deviation
sigma = 0.2

# noisy signal
s = y + sigma * np.random.normal(size=LENGHT)

# %%
plt.figure(figsize=(10, 5))
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=2)
plt.grid()
plt.legend(['noisy', 'original'])
plt.title('Input Signal')
# Out:
# Text(0.5, 1.0, 'Input Signal')

# %% [markdown]
# Define the matrix T containing the polynomials sampled over the window

# %%
t = np.linspace(0, 1, M)
T = np.column_stack([t**i for i in range(N+1)])

# %% [markdown]
# Construct the LPA kernel

# %%
# comput the qr decomposition of WT
# since T has more rows than columns, then qr computes only the first N + 1 columns of Q and the first N + 1 rows of R.
Q, R = np.linalg.qr(W @ T)

#  define Qtilde
Qtilde =  Winv @ Q

# adjust Qtilde with the weights matrix squared.
W2Qtilde = W**2 @ Qtilde

# select the central row of W2Qtilde
row = M // 2

# compute the kernel
# g = np.sum(W2Qtilde[row, l] * W2Qtilde[:, l] for l in range(N + 1))
g = Qtilde[row, :] @ W2Qtilde.T

# flipping, since it is used in convolution
g = g[::-1]

# normalization
g = g / np.sum(g)

# %%
plt.figure()
plt.plot(g, 'rs', linewidth=3)
plt.title(f'filter M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'filter M = 53, N = 2')

# %% [markdown]
# Filtering

# %%
shat = convolve(s, g, 'same')

# %%
plt.figure()
plt.plot(ty, s, 'r.')
plt.plot(ty, y, 'k--', linewidth=3)
plt.plot(ty, shat, 'm-', linewidth=3)
plt.grid()
plt.legend(['noisy', 'original', 'LPA estimate'])
plt.title(f'M = {M:d}, N = {N:d}')
# Out:
# Text(0.5, 1.0, 'M = 53, N = 2')

# %% [markdown]
# Modify the code to use the central, left and right kernels

# %%
N = 3 # only to show more the problem at the edges (pathological)

weights = [
    { 'w': wc, 'label': 'Centered weights'},
    { 'w': wl, 'label': 'Left weights'},
    { 'w': wr, 'label': 'Right weights'},
]
fig, axs = plt.subplots(3, 2, figsize=(20, 18))

for i, w in enumerate(weights):
    # fit the model
    w, label = w['w'], w['label']
    s_hat, g = lib.weighted_LPA(s, w, N, M)

    # plot the filter
    axs[i, 0].plot(g, 'rs', linewidth=3)
    axs[i, 0].grid()
    axs[i, 0].set_title(f'{label}')

    axs[i, 1].plot(ty, s, 'r.')
    axs[i, 1].plot(ty, y, 'k--', linewidth=3)
    axs[i, 1].plot(ty, s_hat, 'm-', linewidth=3)
    axs[i, 1].grid()
    axs[i, 1].legend(['Noisy', 'Original', 'LPA estimate'])
    axs[i, 1].set_title(f'{label}')

plt.tight_layout()
plt.show()
# Out:
# /Users/lorenzobenzoni/Documents/university/labs/MMIM/lib.py:321: RuntimeWarning: divide by zero encountered in divide
#   w_inv = 1 / w
